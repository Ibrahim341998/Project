# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibrahim341998/Project/blob/main/Problem1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem 1
# ##### Build a Python script that detects faces in an image using OpenCV, and saves the headshots of the detected faces to a specified directory. The script should take as input a file path to an image, a directory path to save the headshots, and output the number of faces detected in the image

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Importing the libraries
import cv2
import sys
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import matplotlib.image as mpimg

# %% [markdown]
# #### Code to load an image

# %%
# Passing input image
imagePath = "/content/drive/MyDrive/faces.jpg"
# converting BGR to Grayscale for better results
image = cv2.imread(imagePath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
img_plot = plt.imshow(gray)
plt.show()

# %% [markdown]
# #### code that detects faces in the specified image

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor = 1.3,
    minNeighbors = 3,
    minSize = (30,30)
)
print("Found {0} Faces!".format(len(faces)))
# Next, you will use OpenCV’s .rectangle() method to draw a rectangle around the detected faces
img_no = 0
for (x, y, w, h) in faces:
  cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0), 2)
  roi_color = image[y:y + h,x:x + w]
  print("[INFO] object found. Saving locally.")
  img_no += 1
  cv2.imwrite(str(img_no) + '_faces.jpg', roi_color)
# status of the image to check if the image is detected or not
status = cv2.imwrite('faces_detected.jpg', image)
# printing the status
print("Image face_detected.jpg written to filesystem: ", status)
# Out:
# Found 6 Faces!
# [INFO] object found. Saving locally.
# [INFO] object found. Saving locally.
# [INFO] object found. Saving locally.
# [INFO] object found. Saving locally.
# [INFO] object found. Saving locally.
# [INFO] object found. Saving locally.
# Image face_detected.jpg written to filesystem:  True

# %%
image = "/content/faces_detected.jpg"
img = cv2.imread(image)
img = plt.imshow(img)
plt.show()

# %%
img_faces = "/content/1_faces.jpg"
img_face = cv2.imread(img_faces)
img_face = plt.imshow(img_face)
plt.show()
